# %%
#import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
# %matplotlib inline

# %%
#Read the file
df_train = pd.read_csv('D:/CsuLa/Job2018/Data Science/Dataset/all/train.csv')
df_test = pd.read_csv('D:/CsuLa/Job2018/Data Science/Dataset/all/test.csv')
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# ...

# %% [markdown]
# # Data Cleaning:--

# %%
pd.options.display.max_columns = None
display(df_train)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# 5        6          50       RL         85.0    14115   Pave   NaN      IR1
# 6        7          20       RL         75.0    10084   Pave   NaN      Reg
# 7        8          60       RL          NaN    10382   Pave   NaN      IR1
# 8        9          50       RM         51.0     6120   Pave   NaN      Reg
# 9       10         190       RL         50.0     7420   Pave   NaN      Reg
# 10      11          20       RL         70.0    11200   Pave   NaN      Reg
# ...

# %%
pd.options.display.max_columns = None
display(df_test)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5     1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6     1467          20       RL          NaN     7980   Pave   NaN      IR1
# 7     1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8     1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9     1470          20       RL         70.0     8400   Pave   NaN      Reg
# 10    1471         120       RH         26.0     5858   Pave   NaN      IR1
# ...

# %%
df_train.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
Empty = ['MasVnrType','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2','Electrical','FireplaceQu','GarageType',
        'GarageFinish','GarageQual','GarageCond']
def Clean(df_train,Empty):
    for x in Empty:
        df_train[x] = df_train[x].fillna(0)
Clean(df_train,Empty)

# %%
Mean = ['LotFrontage','MasVnrArea','GarageYrBlt']

def MeanValue(df_train,Mean):
    for x in Mean:
        df_train[x] = df_train[x].fillna(df_train[x].mean())
MeanValue(df_train,Mean)

df_train['SaleCondition'] = df_train['SaleCondition'].replace('NaN','0')

# %%
df_train.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
df_train.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1460.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    22.024023    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    60.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    70.049958    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    79.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
df_test.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage       LotArea Street  \
# count   1459.000000  1459.000000     1455  1232.000000   1459.000000   1459
# unique          NaN          NaN        5          NaN           NaN      2
# top             NaN          NaN       RL          NaN           NaN   Pave
# freq            NaN          NaN     1114          NaN           NaN   1453
# mean    2190.000000    57.378341      NaN    68.580357   9819.161069    NaN
# std      421.321334    42.746880      NaN    22.376841   4955.517327    NaN
# min     1461.000000    20.000000      NaN    21.000000   1470.000000    NaN
# 25%     1825.500000    20.000000      NaN    58.000000   7391.000000    NaN
# 50%     2190.000000    50.000000      NaN    67.000000   9399.000000    NaN
# 75%     2554.500000    70.000000      NaN    80.000000  11517.500000    NaN
# max     2919.000000   190.000000      NaN   200.000000  56600.000000    NaN
#
# ...

# %%
fill = ['MSZoning','Utilities','Exterior1st','Exterior2nd','MasVnrType','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1',
       'BsmtFinType2','KitchenQual','Functional','FireplaceQu','GarageType','GarageFinish',
       'GarageQual','GarageCond','SaleType']

def FillFun(df_train,fill):
    for x in fill:
        df_train[x] = df_train[x].fillna(0)
FillFun(df_train,fill)

df_test.replace('NaN','0')
df_train['SaleCondition'] = df_train['SaleCondition'].replace('NaN','0')

# %%
Mean2 = ['LotFrontage','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','BsmtFullBath','BsmtHalfBath',
        'GarageYrBlt','GarageCars','GarageArea']

def MeanValue2(df_train,Mean2):
    for x in Mean2:
        df_train[x] = df_train[x].fillna(df_train[x].mean())
MeanValue2(df_train,Mean2)

# %%
df_test.drop(['Alley','PoolQC','Fence','MiscFeature'],axis=1,inplace=True)

# %%
df_test.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage       LotArea Street  \
# count   1459.000000  1459.000000     1455  1232.000000   1459.000000   1459
# unique          NaN          NaN        5          NaN           NaN      2
# top             NaN          NaN       RL          NaN           NaN   Pave
# freq            NaN          NaN     1114          NaN           NaN   1453
# mean    2190.000000    57.378341      NaN    68.580357   9819.161069    NaN
# std      421.321334    42.746880      NaN    22.376841   4955.517327    NaN
# min     1461.000000    20.000000      NaN    21.000000   1470.000000    NaN
# 25%     1825.500000    20.000000      NaN    58.000000   7391.000000    NaN
# 50%     2190.000000    50.000000      NaN    67.000000   9399.000000    NaN
# 75%     2554.500000    70.000000      NaN    80.000000  11517.500000    NaN
# max     2919.000000   190.000000      NaN   200.000000  56600.000000    NaN
#
# ...

# %%
data = ['MSZoning'
,'Street'
,'LotShape'
,'LandContour'
,'Utilities'
,'LotConfig'
,'LandSlope'
,'Neighborhood'
,'Condition1'
,'Condition2'
,'BldgType'
,'HouseStyle'
,'RoofStyle'
,'RoofMatl'
,'Exterior1st'
,'Exterior2nd'
,'MasVnrType'
,'ExterQual'
,'ExterCond'
,'Foundation'
,'BsmtQual'
,'BsmtCond'
,'BsmtExposure'
,'BsmtFinType1'
,'BsmtFinType2'
,'Heating'
,'HeatingQC'
,'CentralAir'
,'Electrical'
,'KitchenQual'
,'Functional'
,'FireplaceQu'
,'GarageType'
,'GarageFinish'
,'GarageQual'
,'GarageCond'
,'PavedDrive'
,'SaleType'
,'SaleCondition']

# %%
df_train[data] = df_train[data].astype('category')
df_train.dtypes
# Out:
# Id                  int64
# MSSubClass          int64
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
# Street           category
# LotShape         category
# LandContour      category
# Utilities        category
# LotConfig        category
# LandSlope        category
# Neighborhood     category
# Condition1       category
# Condition2       category
# BldgType         category
# HouseStyle       category
# OverallQual         int64
# OverallCond         int64
# YearBuilt           int64
# YearRemodAdd        int64
# RoofStyle        category
# RoofMatl         category
# Exterior1st      category
# Exterior2nd      category
# MasVnrType       category
# MasVnrArea        float64
# ExterQual        category
# ExterCond        category
# Foundation       category
# BsmtQual         category
#                    ...
# BsmtHalfBath        int64
# FullBath            int64
# HalfBath            int64
# BedroomAbvGr        int64
# ...

# %%
def display(df_train,data):
    for x in data:
        df_train[x] = df_train[x].cat.codes
display(df_train,data)

# %%
df_test[data] = df_test[data].astype('category')
df_test.dtypes
# Out:
# Id                  int64
# MSSubClass          int64
# MSZoning         category
# LotFrontage       float64
# LotArea             int64
# Street           category
# LotShape         category
# LandContour      category
# Utilities        category
# LotConfig        category
# LandSlope        category
# Neighborhood     category
# Condition1       category
# Condition2       category
# BldgType         category
# HouseStyle       category
# OverallQual         int64
# OverallCond         int64
# YearBuilt           int64
# YearRemodAdd        int64
# RoofStyle        category
# RoofMatl         category
# Exterior1st      category
# Exterior2nd      category
# MasVnrType       category
# MasVnrArea        float64
# ExterQual        category
# ExterCond        category
# Foundation       category
# BsmtQual         category
#                    ...
# BsmtFullBath      float64
# BsmtHalfBath      float64
# FullBath            int64
# HalfBath            int64
# ...

# %%
def display(df_test,data):
    for x in data:
        df_test[x] = df_test[x].cat.codes
display(df_test,data)

# %%
df_train.head()
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0   1          60         3         65.0     8450       1         3
# 1   2          20         3         80.0     9600       1         3
# 2   3          60         3         68.0    11250       1         0
# 3   4          70         3         60.0     9550       1         0
# 4   5          60         3         84.0    14260       1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          4          0             5           2
# 1            3          0          2          0            24           1
# 2            3          0          4          0             5           2
# 3            3          0          0          0             6           2
# 4            3          0          2          0            15           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df_test.head()
# Out:
#      Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  LotShape  \
# 0  1461          20         2         80.0    11622       1         3
# 1  1462          20         3         81.0    14267       1         0
# 2  1463          60         3         74.0    13830       1         0
# 3  1464          60         3         78.0     9978       1         0
# 4  1465         120         3         43.0     5005       1         0
#
#    LandContour  Utilities  LotConfig  LandSlope  Neighborhood  Condition1  \
# 0            3          0          4          0            12           1
# 1            3          0          0          0            12           2
# 2            3          0          4          0             8           2
# 3            3          0          4          0             8           2
# 4            1          0          4          0            22           2
#
#    Condition2  BldgType  HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
X = df_train.drop('SalePrice',axis=1).values
y = df_train['SalePrice'].values

# %%
X.shape
# Out:
# (1460, 76)

# %%
y.shape
# Out:
# (1460,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (1022, 76)
# (1022,)

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (438, 76)
# (438,)

# %%
print(X_test)
print('\n')
print(y_test)
# Out:
# [[2.590e+02 6.000e+01 3.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]
#  [2.680e+02 7.500e+01 3.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]
#  [2.890e+02 2.000e+01 3.000e+00 ... 2.010e+03 8.000e+00 4.000e+00]
#  ...
#  [1.173e+03 1.600e+02 1.000e+00 ... 2.008e+03 8.000e+00 4.000e+00]
#  [1.168e+03 6.000e+01 3.000e+00 ... 2.006e+03 8.000e+00 4.000e+00]
#  [5.300e+02 2.000e+01 3.000e+00 ... 2.007e+03 8.000e+00 2.000e+00]]
#
#
# [231500 179500 122000  84500 142000 325624 285000 151000 195000 275000
#  175000  61000 174000 385000 230000  87000 125000  98600 260000 143000
#  124000 122500 236500 337500  76000 187000 128000 179000 485000 122500
#  106000 118000 127000  80000 153000 360000 132000  85500 262280 112000
#  131000 139000  87000 135000 181000 163500 116900 159895 244600 294000
#   97000 295000 120500 239500 194000 115000 119500 180000 118000 178000
#  167000 267000  82000 133900 167000 132500 135000 248000 160000 144500
# ...

# %% [markdown]
# ## Knn:--

# %%
from sklearn.neighbors import KNeighborsClassifier

# In the following line, "knn" is instantiated as an "object" of KNeighborsClassifier "class". 

k = 1
knn = KNeighborsClassifier(n_neighbors=k)

# Training ONLY on the training set:

knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=1, p=2,
#            weights='uniform')

# %%
# Testing on the testing set:

y_predict_knn = knn.predict(X_test)

print(y_predict_knn)
# Out:
# [197900 210000 128500  75500 149900 313000 265979 151000 225000 184000
#   82500 114500 181000 256000 213000 119000  85000 160000 143000 110000
#  142000 167500 251000 318000 109500 176000  93000 189000 582933 113000
#  219500 119500 124900 133000 145000 402861 139000  86000 305000 230000
#  223500 173000  80000 128500 197000 149500  66500 215000 191000 129000
#   82500 129000 129500 253000 179600 105000 135500 155000 102000 222500
#  165000 342643 105900 129900 175000 109000 178900 185000 135000 185000
#  129000 164700 345000 175900 140000 254000 105000 105000 244000 196000
#  260000 145000 137500 179900 165150 145000 184100 163500 167500 206900
#  196000 137500 122000 126000 135000 105000 112500 150750 112500 165000
#  206900 135960 154900 124000 126000  95000 152000 178000 174500 305000
#  178900 169500 139950 181134 227875 173000 192000 109000 152000 181000
#  140000 200141 225000 124500 183900 218000 214000 112000 239000 153900
# ...

# %%
from sklearn.metrics import r2_score
knn_accuracy = r2_score(y_test,y_predict_knn)
print(knn_accuracy)
# Out:
# 0.5614963982087416

# %%
for i in range(1,16):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    knn_pred = knn.predict(X_test)
    print("Accuracy for {} neighbours".format(i), r2_score(y_test, knn_pred))
# Out:
# Accuracy for 1 neighbours 0.5614963982087416
# Accuracy for 2 neighbours 0.40903321837037754
# Accuracy for 3 neighbours 0.3196819899851028
# Accuracy for 4 neighbours 0.22711470237924858
# Accuracy for 5 neighbours 0.15791608123567025
# Accuracy for 6 neighbours 0.09574982760599193
# Accuracy for 7 neighbours 0.02832574431904744
# Accuracy for 8 neighbours -0.013350806965158002
# Accuracy for 9 neighbours -0.09541770988940157
# Accuracy for 10 neighbours -0.15189337631265776
# Accuracy for 11 neighbours -0.18791725011723348
# Accuracy for 12 neighbours -0.2300625926115658
# Accuracy for 13 neighbours -0.24365081536746525
# Accuracy for 14 neighbours -0.2688722168680555
# Accuracy for 15 neighbours -0.2550590043630465

# %%
"""from sklearn.utils import check_array

def mean_absolute_percentage_error(y_test, y_predict): 
    y_test, y_predict = check_array(y_test, y_predict)
    return np.mean(np.abs((y_test - y_predict) / y_test)) * 100

mean_absolute_percentage_error(y_test, y_predict)"""
# Out:
# 'from sklearn.utils import check_array\n\ndef mean_absolute_percentage_error(y_test, y_predict): \n    y_test, y_predict = check_array(y_test, y_predict)\n    return np.mean(np.abs((y_test - y_predict) / y_test)) * 100\n\nmean_absolute_percentage_error(y_test, y_predict)'

# %%
results = pd.DataFrame()

results['actual'] = y_test 
results['prediction'] = y_predict_knn 

print(results)
# Out:
#      actual  prediction
# 0    231500      197900
# 1    179500      210000
# 2    122000      128500
# 3     84500       75500
# 4    142000      149900
# 5    325624      313000
# 6    285000      265979
# 7    151000      151000
# 8    195000      225000
# 9    275000      184000
# 10   175000       82500
# 11    61000      114500
# 12   174000      181000
# 13   385000      256000
# 14   230000      213000
# 15    87000      119000
# 16   125000       85000
# 17    98600      160000
# 18   260000      143000
# 19   143000      110000
# 20   124000      142000
# 21   122500      167500
# 22   236500      251000
# 23   337500      318000
# 24    76000      109500
# 25   187000      176000
# 26   128000       93000
# 27   179000      189000
# 28   485000      582933
# 29   122500      113000
# ..      ...         ...
# 408  212900      295493
# 409  145000      148000
# 410  162900      140200
# 411  299800      236000
# 412  175000      222000
# 413  125000      140000
# ...

# %% [markdown]
# ## Decision Tree:--

# %%
# The following line will import DecisionTreeClassifier "Class"
# DecisionTreeClassifier is name of a "sklearn class" to perform "Decision Tree Classification" 

from sklearn.tree import DecisionTreeClassifier

# "my_decisiontree" is instantiated as an "object" of DecisionTreeClassifier "class". 

my_decisiontree = DecisionTreeClassifier()

# We can use the method "fit" of the objects "my_decisiontree" along with training dataset and labels to train the model.

my_decisiontree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
# Testing on the testing set:

y_predict_decisiontree = my_decisiontree.predict(X_test)

print(y_predict_decisiontree)
# Out:
# [213000 136900 114500  81000 149500 159000 325000 144152 215000 185000
#  175000  88000 175900 324000 239799 110000 131500 175500 153000 149900
#  127500 137000 204900 402861 119900 158900 251000 230000 582933  98000
#  137000  91500 125000 138887 159000 318000 121000 100000 260000 120000
#  140000 145000 119900 132500 175000 162500 112500 112000 248900 205000
#  125000 239799 145000 199900 262000 119000 137000 189000 139400 152000
#  148000 235000 119900 133000 150750 124500 114504 194500 155000 142000
#  213250 107400 335000 152000 210000 185850 160000 154900 465000 246578
#  185000 109000 124500 149700 202665 140000 150750 156000 239000 158900
#  177000 167900 123600  82000 109900 190000 110000 190000 134800 142000
#  155000 129500 173000 120500 125500 173000 178900 162000 156932 402000
#  140000 179000 142500 192500 233000 216837 193879 129500 215000 266000
#  179900 256300 350000  79900 130000 171000 179900 143250 210000 207500
# ...

# %%
from sklearn.metrics import r2_score
decisiontree_accuracy = r2_score(y_test,y_predict_decisiontree)
decisiontree_accuracy
# Out:
# 0.6276979684825124

# %%
from sklearn import metrics

# Calculating "Mean Square Error" (MSE):
mse = metrics.mean_squared_error(y_test, y_predict_decisiontree)

# Using numpy sqrt function to take the square root and calculate "Root Mean Square Error" (RMSE)
rmse = np.sqrt(mse)

print(rmse)
# Out:
# 51559.1819808263

# %% [markdown]
# ### Cross Validation:--

# %%
from sklearn.cross_validation import cross_val_score

my_decisiontree = DecisionTreeClassifier()

r2_score_list = cross_val_score(my_decisiontree, X, y, cv=10,scoring='r2')

r2_score_list
# Out:
# C:\Users\parth\Anaconda3\envs\py3.6\lib\site-packages\sklearn\cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# C:\Users\parth\Anaconda3\envs\py3.6\lib\site-packages\sklearn\cross_validation.py:553: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of labels for any class cannot be less than n_folds=10.
#   % (min_labels, self.n_folds)), Warning)
# array([ 0.50422103,  0.32260184,  0.41548469,  0.33899765, -0.18687093,
#         0.22572539, -0.0160776 , -1.64042322, -0.99485088, -0.09743241])

# %%
# use average of accuracy values as final result
accuracy_cv = r2_score_list.mean()

print(accuracy_cv)
# Out:
# -0.112862442490819

# %% [markdown]
# ## Random Forest:--

# %%
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
my_RandomForest = RandomForestRegressor(n_estimators = 19, bootstrap = True, random_state=2)
my_RandomForest.fit(X_train, y_train)
# Out:
# C:\Users\parth\Anaconda3\envs\py3.6\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=19, n_jobs=1,
#            oob_score=False, random_state=2, verbose=0, warm_start=False)

# %%
# Testing on the testing set:

y_predict_randomforest = my_RandomForest.predict(X_test)

print(y_predict_randomforest)
# Out:
# [208986.05263158 151839.63157895 116647.36842105  81131.57894737
#  152952.63157895 320677.         304263.84210526 146522.10526316
#  222105.78947368 270590.10526316 181552.63157895  79310.52631579
#  204953.21052632 349810.94736842 251134.15789474 100523.68421053
#  118574.10526316 128125.10526316 237254.47368421 129652.63157895
#  122065.78947368 130965.94736842 260234.52631579 327590.73684211
#   93331.57894737 188884.21052632 128598.89473684 191407.36842105
#  439776.89473684 122961.84210526 121915.42105263 102810.52631579
#  118855.68421053  92842.10526316 155278.94736842 342424.78947368
#  120013.15789474  84084.21052632 254778.42105263 108992.10526316
#  150933.36842105 148134.21052632 107360.52631579 121642.10526316
#  178710.52631579 177923.68421053 140368.42105263 179114.68421053
#  257081.73684211 253208.36842105 109228.94736842 355697.31578947
#  108971.05263158 222600.         220926.63157895 109147.78947368
# ...

# %%
from sklearn.metrics import r2_score
RandomForest_accuracy = r2_score(y_test,y_predict_randomforest)
RandomForest_accuracy
# Out:
# 0.8760791308968179

# %%
from sklearn.model_selection import model_selection

seed = 7
num_trees = 120
max_features = 10
kfold2 = model_selection.KFold(n_splits=10, random_state=seed)
model2 = RandomForestRegressor(n_estimators=num_trees, max_features=max_features)
results2 = model_selection.cross_val_score(model2, X, y, cv=kfold2)
print(results2.mean())
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-49-cd8cb44c8cd2> in <module>()
# ----> 1 from sklearn.model_selection import model_selection
#       2
#       3 seed = 7
#       4 num_trees = 120
#       5 max_features = 10
#
# ImportError: cannot import name 'model_selection'

# %% [markdown]
# ## Statstics:--

# %%
import statsmodels.api as sm
from scipy import stats
X2 = sm.add_constant(X)
est = sm.OLS(y,X2)
est2 = est.fit()
est2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              SalePrice   R-squared:                       0.850
# Model:                            OLS   Adj. R-squared:                  0.842
# Method:                 Least Squares   F-statistic:                     107.6
# Date:                Tue, 14 Aug 2018   Prob (F-statistic):               0.00
# Time:                        14:09:24   Log-Likelihood:                -17159.
# No. Observations:                1460   AIC:                         3.447e+04
# Df Residuals:                    1386   BIC:                         3.486e+04
# Df Model:                          73
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...
